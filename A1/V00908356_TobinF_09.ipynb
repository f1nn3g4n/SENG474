# %%
# !pip freeze
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install pydotplus
# !pip3 install six

# %% [markdown]
# Problem 9: Guessing the source

# %% [markdown]
# try a log, see what plot you get.
# normalize by shift can be good too

# %%
# %ls
