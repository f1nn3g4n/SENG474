# %%
# !pip freeze
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install pydotplus
# !pip3 install six

# %% [markdown]
# Problem 4: Library, help me out!

# %%
from sklearn import tree
import pandas as pd
import numpy as np

# Change to wherever the file elections_clean.csv is being stored
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Year_5/SENG474/SENG474/A1
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Year_5/SENG474/SENG474/A1

# %%
df = pd.read_csv('elections_clean.csv', sep='\t')

clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf = clf.fit(df, df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-205e066cb9f0> in <module>
# ----> 1 clf = clf.fit(df, df.columns)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
#     165             X, y = self._validate_data(
# --> 166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#     168             if issparse(X):
#
# ...
