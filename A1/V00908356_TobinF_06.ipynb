# %%
# !pip freeze
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install pydotplus
# !pip3 install six

# %% [markdown]
# Problem 1: The American Job
#
# 1. Bad data

# %%
# %ls

# %% [markdown]
# regress: expanding from just using categorical data
# - .5 max points for sklearn, not 5
#
# cross-validation: decide on param of decision trees, depth or something. opposed to grid search tuning
